# %%
import numpy as np, plottools as pl, healpy as hp, local, tools_cmb, binning as bn
from matplotlib.pyplot import *
import warnings
warnings.filterwarnings("ignore")

# %%
aobj = local.init_analysis()

# %%
G20 = hp.fitsfunc.read_map(aobj.fGmask,field=0)

# %%
hp.mollview(G20)

# %%
Lmask = hp.fitsfunc.read_map(aobj.flens['mask'])

# %%
hp.mollview(Lmask)

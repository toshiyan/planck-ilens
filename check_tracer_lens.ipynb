# %%
import numpy as np, plottools as pl, healpy as hp, local, tools_cmb, tools_cib, binning as bn, curvedsky as cs, pickle
from matplotlib.pyplot import *
import warnings
warnings.filterwarnings("ignore")

# %%
aobj = local.init_analysis()

# %%
wind = hp.fitsfunc.read_map(aobj.flens['mask'])

# %%
kalm = hp.read_alm(aobj.flens['MV'][0])
klm = cs.utils.lm_healpy2healpix(kalm,4096)[:2000+1,:2000+1]

# %%
kmap = cs.utils.hp_alm2map(2048,2000,2000,klm)
hp.mollview(kmap)

# %%
w2 = np.mean(wind**2)

# %%
ckk = cs.utils.alm2cl(2000,klm)/w2

# %%
L, nkk = np.loadtxt('/global/cscratch1/sd/toshiyan/PR3/lens/COM_Lensing_4096_R3.00/MV/nlkk.dat',unpack=True,usecols=(0,2))

# %%
pl.plot_1dstyle(xlog=True,ylog=True,ymin=1e-9,ymax=1e-5)
plot(ckk)
plot(aobj.ckk)
plot(L,nkk)

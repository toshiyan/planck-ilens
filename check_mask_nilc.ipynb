# %%
import numpy as np, healpy as hp, local, warnings
warnings.filterwarnings("ignore")

# %%
aobj = local.init_analysis(wind='LG40')

# %%
Lmask = hp.fitsfunc.read_map(aobj.flens['mask'],verbose=False)

# %%
Gmask = hp.fitsfunc.read_map(aobj.fGmask,field=2,verbose=False)
# Out:
# /global/homes/t/toshiyan/.local/lib/python3.7/site-packages/healpy/fitsfunc.py:426: UserWarning: No INDXSCHM keyword in header file : assume IMPLICIT
#   warnings.warn("No INDXSCHM keyword in header file : " "assume {}".format(schm))

# %%
NilcT = hp.fitsfunc.read_map('../data/PR3_local/mask/COM_CMB_IQU-nilc_2048_R3.00_full.fits',field=3)

# %%
NilcP = hp.fitsfunc.read_map('../data/PR3_local/mask/COM_CMB_IQU-nilc_2048_R3.00_full.fits',field=4)

# %%
hp.cartview(NilcT)
hp.cartview(NilcP)

# %%
hp.cartview(Lmask*Gmask)

# %%
hp.mollview((1-NilcT)*Gmask*Lmask)
hp.mollview((1-NilcT*NilcP)*Gmask*Lmask)

# %%
print(np.max((1-NilcT)*Gmask*Lmask))
# Out:
# 1.0
